# %%
# %run death-lessons.ipynb # gets pdf urls
# Out:
# fetched['https://www.judiciary.uk/publications/philippa-day/', 'https://www.judiciary.uk/publications/lucy-colgate/', 'https://www.judiciary.uk/publications/michael-dent-jones/', 'https://www.judiciary.uk/publications/gillian-mckinlay/', 'https://www.judiciary.uk/publications/robert-hardy/', 'https://www.judiciary.uk/publications/ruth-jones/', 'https://www.judiciary.uk/publications/carole-mitchell/', 'https://www.judiciary.uk/publications/jack-goodwin/', 'https://www.judiciary.uk/publications/michael-dobson/', 'https://www.judiciary.uk/publications/valeria-biggs/']
# ...

# %%
# %run death-lessons-part-deux.ipynb # gets pdf
# Out:
# Downloading: downloads/Phillipa-Day-2021-0043.pdf
# Downloading: downloads/Lucy-Colgate-2021-0042-Redacted.pdf
# Downloading: downloads/Michael-Dent-Jones-2021-0041-Redacted.pdf
# Downloading: downloads/Gillian-McKinlay-2021-0040.pdf
# Downloading: downloads/Robert-Hardy-2021-0039-Redacted.pdf
# Downloading: downloads/Ruth-Jones-2021-0038-Redacted.pdf
# Downloading: downloads/Carole-Mitchell-2021-0037-Redacted.pdf
# Downloading: downloads/Jack-Goodwin-2021-0036-Redacted.pdf
# Downloading: downloads/Michael-Dobson-2021-0035-Redacted.pdf
# Downloading: downloads/Valeria-Biggs-2021-0034-Redacted.pdf
# Downloading: downloads/Lily-Mai-George-2021-0033-Redacted.pdf
# Downloading: downloads/Jason-ORourke-2021-0032-Redacted.pdf
# Downloading: downloads/2020-0295-Response-from-Highways-England-Redacted.pdf
# Downloading: downloads/2020-0293-Response-from-West-Sussex-County-Council-Redacted.pdf
# ...

# %%
# %run death-lessons-part-trois.ipynb # extracts pdf text from real pdfs
# Out:
# 20201018
# processing downloads/Donald-Till-2018-0013_Redacted.pdf
#
# processing downloads/Cooke-2014-0485.pdf
#
# processing downloads/2016-0288-Response-by-Avon-and-Wiltshire-NHS-Trust.pdf
#
# processing downloads/Philip-Owen-2019-0330_Redacted.pdf
#
# processing downloads/2015-0081-Response-by-Lewisham-Greenwich-NHS-Trust.pdf
#
# processing downloads/Dennis-Redmore-2017-0315.pdf
#
# processing downloads/James-Quinton-2018-0056_Redacted.pdf
#
# processing downloads/2020-0293-Response-from-West-Sussex-County-Council-Redacted.pdf
#
# processing downloads/Travis-2014-0101.pdf
#
# processing downloads/Rose-Fowler-2016-0153.pdf
#
# processing downloads/2019-0378-Royal-College-of-General-Practitioners.pdf
#
# Text extraction is not allowed: <_io.BufferedReader name='downloads/2019-0378-Royal-College-of-General-Practitioners.pdf'>
# Encountered unknown error. Continuing.
# processing downloads/2018-0386-Response-by-Arriva-1.pdf
#
# processing downloads/Ronald-CLARK-2019-0151.pdf
#
# ...

# %%
# %run death-lessons-part-quatre.ipynb # get some metadata
# Out:
# True

# %%
# %run death-lessons-part-cinq.ipynb # extract pdf text from scanned documents i.e ocr action
# Out:
# Unable to get page count.
# I/O Error: Couldn't open file 'downloads/Calvo-2016-0192_page3': No such file or directory.
#
#   Encountered unknown error. Continuing.
# Unable to get page count.
# I/O Error: Couldn't open file 'downloads/Rastislav-Petrisko-2018-0067_Redacted_page3': No such file or directory.
#
#   Encountered unknown error. Continuing.
# Unable to get page count.
# I/O Error: Couldn't open file 'downloads/Knox-Hooke-2016-0278_page2': No such file or directory.
#
#   Encountered unknown error. Continuing.
# Unable to get page count.
# I/O Error: Couldn't open file 'downloads/Ajakaiye-2016-0209_page4': No such file or directory.
#
#   Encountered unknown error. Continuing.
# Unable to get page count.
# I/O Error: Couldn't open file 'downloads/Harris-2013-0347_page3': No such file or directory.
#
#   Encountered unknown error. Continuing.
# Unable to get page count.
# ...

# %%
# %run death-lessons-part-six.ipynb # clean up metadata

# %%
# %run death-lessons-part-sept.ipynb # add text we extracted to the metadata
